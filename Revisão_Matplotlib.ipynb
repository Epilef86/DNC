# %% [markdown]
# <a href="https://colab.research.google.com/github/Epilef86/DNC/blob/main/Revis%C3%A3o_Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
#Gerando gráficos pelos pontos
xpoints = np.array([0,6])
ypoints = np.array([0,250])

plt.plot(xpoints, ypoints)
plt.show()

# %%
#Exibindo apenas os pontos
xpoints = np.array([0,6])
ypoints = np.array([0,250])

plt.plot(xpoints, ypoints, 'o')
plt.show()

# %%
df = pd.read_csv('/content/kc_house_data.csv')
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
agg_zip = df.groupby(['bedrooms'])['price'].agg('mean').reset_index()
display(agg_zip)
# Out:
#     bedrooms         price
# 0          0  4.095038e+05
# 1          1  3.176429e+05
# 2          2  4.013727e+05
# 3          3  4.662321e+05
# 4          4  6.354195e+05
# 5          5  7.865998e+05
# 6          6  8.255206e+05
# 7          7  9.511847e+05
# 8          8  1.105077e+06
# 9          9  8.939998e+05
# 10        10  8.193333e+05
# 11        11  5.200000e+05
# 12        33  6.400000e+05

# %%
#Analisando graficamente por gráfico de barra
#Função pra ajustar o tamanho da figura
fig = plt.figure(figsize=(20,5))
#gGráfico de barra, lembrando que o primeiro parâmetro é sempre o eixo x, que é a coluna zipcode
plt.bar(agg_zip['bedrooms'], agg_zip['price'], color='green', width= 0.9)
#Legenda do eixo y
plt.ylabel("Preço")
#bold --> negrito
plt.title('Preço', loc='center', fontsize=18, fontweight = 'bold', color='blue')
# Out:
# Text(0.5, 1.0, 'Preço')

# %%
fig = plt.figure()
#gGráfico de barra deitado, lembrando que o primeiro parâmetro é sempre o eixo x, que é a coluna zipcode
plt.barh(agg_zip['bedrooms'], agg_zip['price'])
#Legenda do eixo y
plt.ylabel("Preço")
#bold --> negrito
plt.title('Preço', loc='center', fontsize=18, fontweight = 'bold', color='blue')
plt.show()

# %%
#Tem algum erro que não identifiquei
#avg_df = df.groupby(['zipcode']).agg('mean').reset_index()
#ax = avg_df.plot.bar(x='eixo x', y='eixo y')

# %%
fig = plt.figure(figsize=(15,5))
#Escala eixo x
plt.xticks([100,200,300])
#Escala eixo y
plt.yticks([250,1000,1750])
#Gráfico de histograma   .....bins--> quantidade de barras que vai ter, edgecolor --> borda
plt.hist(df['grade'], edgecolor='red', color='green', bins=10)
plt.show()

# %%
plt.hist(df['bathrooms'])
plt.show()

# %%
#Gráfico de Linha
fig = plt.figure(figsize=(12,6))
plt.xlabel('yr_built')
plt.ylabel('sqft_lot15')
x = df['yr_built']
y = df['sqft_lot15']

plt.plot(x,y,color='green', linewidth='2')
plt.show()

# %%
#Gráfico de dispersão ou scatter  
x = df['sqft_living15']
y = df['floors']
plt.scatter(x,y)
plt.show()
